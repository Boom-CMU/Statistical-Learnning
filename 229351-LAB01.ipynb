# %% [markdown]
# <a href="https://colab.research.google.com/github/Boom-CMU/Statistical-Learnning/blob/main/229351-LAB01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ปฏิบัติการครั้งที่ 1 กระบวนวิชา 229351 Statistical Learning for Data Science
#
# คำชี้แจง
#
# 1. ให้เริ่มทำปฏิบัติการจาก colab notebook ที่กำหนดให้ **เมื่อเสร็จแล้วให้ทำการ share** จากนั้นส่ง link มาใน mango canvas
#
# ในขั้นตอนแรก ขอให้ download ไฟล์ที่
#
# http://donlapark.pages.dev/229351/data/housing.csv

# %%
import pandas as pd #dataframes
import numpy as np #matrices
import matplotlib.pyplot as plt #for plotting

# %matplotlib inline

# !wget http://donlapark.pages.dev/229351/data/housing.csv
# Out:
# --2026-06-19 16:57:55--  http://donlapark.pages.dev/229351/data/housing.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 172.66.47.56, 172.66.44.200, 2a06:98c1:3120::, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.47.56|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://donlapark.pages.dev/229351/data/housing.csv [following]
# --2026-06-19 16:57:55--  https://donlapark.pages.dev/229351/data/housing.csv
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|172.66.47.56|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1423529 (1.4M) [text/csv]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]   1.36M  --.-KB/s    in 0.02s
#
# 2026-06-19 16:57:55 (54.4 MB/s) - ‘housing.csv’ saved [1423529/1423529]

# %%
import pandas as pd #dataframes

# Reading csv file

housing = pd.read_csv("housing.csv")

# %%
# Showing at the top rows
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# ## Basic data exploration

# %%
# Data's shape
housing.shape
# Out:
# (20640, 10)

# %%
# Data's information

housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# Which variable has missing data?

# %%
# Drop rows with missing data

housing = housing.dropna()

# %%
# Data's information again

housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
# Data's summary statistics
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20433.000000
# mean        206864.413155
# std         115435.667099
# min          14999.000000
# 25%         119500.000000
# 50%         179700.000000
# 75%         264700.000000
# max         500001.000000

# %% [markdown]
# ## Exercise 1
#
# 1. Download ไฟล์ข้อมูลที่
#   http://donlapark.pages.dev/229351/data/Advertising.csv
#   ซึ่งเป็นข้อมูลของผลการขายสินค้าอย่างหนึ่ง (Sales) กับการโฆษณาผ่านทาง TV, Radio, Newspaper
# 2. สร้าง dataframe ชื่อว่า **Ads** โดยใช้ข้อมูลชุดนี้
# 3. ดูข้อมูล 5 แถวแรกของ `Ads`
# 4. ตรวจสอบว่ามีข้อมูลที่หายไปหรือไม่
# 5. แสดงค่าสถิติพรรณนา (Descriptive statistics) ของตัวแปรต่างๆ

# %%
# WRITE YOUR CODE HERE

# !wget http://donlapark.pages.dev/229351/data/Advertising.csv

Ads = pd.read_csv("Advertising.csv")

Ads.head()

Ads.isna().sum()

Ads.describe()
# Out:
# --2026-06-19 19:48:37--  http://donlapark.pages.dev/229351/data/Advertising.csv
# Resolving donlapark.pages.dev (donlapark.pages.dev)... 188.114.96.0, 188.114.97.0, 2606:4700:310c::ac42:2cc8, ...
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|188.114.96.0|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://donlapark.pages.dev/229351/data/Advertising.csv [following]
# --2026-06-19 19:48:37--  https://donlapark.pages.dev/229351/data/Advertising.csv
# Connecting to donlapark.pages.dev (donlapark.pages.dev)|188.114.96.0|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3870 (3.8K) [text/csv]
# Saving to: ‘Advertising.csv.2’
#
# Advertising.csv.2   100%[===================>]   3.78K  --.-KB/s    in 0s
#
# 2026-06-19 19:48:37 (46.8 MB/s) - ‘Advertising.csv.2’ saved [3870/3870]
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# Your answers here:

# %% [markdown]
# ## Calling, indexing & modifying dataframes

# %%
# Indexing a column
Ads[["TV", "Radio", "Newspaper"]]
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
housing[["longitude", "latitude", "housing_median_age"]]
# Out:
#        longitude  latitude  housing_median_age
# 0        -122.23     37.88                41.0
# 1        -122.22     37.86                21.0
# 2        -122.24     37.85                52.0
# 3        -122.25     37.85                52.0
# 4        -122.25     37.85                52.0
# ...          ...       ...                 ...
# 20635    -121.09     39.48                25.0
# 20636    -121.21     39.49                18.0
# 20637    -121.22     39.43                17.0
# 20638    -121.32     39.43                18.0
# 20639    -121.24     39.37                16.0
#
# [20433 rows x 3 columns]

# %% [markdown]
# `ocean_proximity` is categorical. Let's count its values.

# %%
# Count values in a column

Ads["Sales"].value_counts()
# Out:
# Sales
# 9.7     5
# 12.9    4
# 15.9    4
# 11.7    4
# 10.6    3
#        ..
# 17.6    1
# 6.7     1
# 9.9     1
# 5.9     1
# 25.5    1
# Name: count, Length: 121, dtype: int64

# %%
# Indexing rows by row id's
Ads.loc[0]
# Out:
# TV           230.1
# Radio         37.8
# Newspaper     69.2
# Sales         22.1
# Name: 0, dtype: float64

# %%
# Indexing rows by row indices

Ads.iloc[0]
# Out:
# TV           230.1
# Radio         37.8
# Newspaper     69.2
# Sales         22.1
# Name: 0, dtype: float64

# %%
# Indexing both rows and columns

Ads.loc[0:5]
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9
# 5    8.7   48.9       75.0    7.2

# %% [markdown]
# ## Basic statistics of a variable

# %%
# Column's statistics
Ads["Sales"].describe()
# Out:
# count    200.000000
# mean      14.022500
# std        5.217457
# min        1.600000
# 25%       10.375000
# 50%       12.900000
# 75%       17.400000
# max       27.000000
# Name: Sales, dtype: float64

# %% [markdown]
# ## Selecting rows based on conditions

# %%
# Indexing rows based on one condition

Ads[Ads["Sales"] > 20]
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 15   195.4   47.7       52.9   22.4
# 17   281.4   39.6       55.8   24.4
# 30   292.9   28.3       43.2   21.4
# 36   266.9   43.8        5.0   25.4
# 39   228.0   37.7       32.0   21.5
# 42   293.6   27.7        1.8   20.7
# 47   239.9   41.5       18.5   23.2
# 52   216.4   41.7       39.6   22.6
# 53   182.6   46.2       58.7   21.2
# 54   262.7   28.8       15.9   20.2
# 55   198.9   49.4       60.0   23.7
# 58   210.8   49.6       37.7   23.8
# 61   261.3   42.7       54.7   24.2
# 69   216.8   43.9       27.2   22.3
# 84   213.5   43.0       33.8   21.7
# 93   250.9   36.5       72.3   22.2
# 98   289.7   42.3       51.2   25.4
# 101  296.4   36.3      100.9   23.8
# 104  238.2   34.3        5.3   20.7
# 111  241.7   38.0       23.2   21.8
# 128  220.3   49.0        3.2   24.7
# 137  273.7   28.9       59.7   20.8
# 139  184.9   43.9        1.7   20.7
# 142  220.5   33.2       37.9   20.1
# 147  243.2   49.0       44.3   25.4
# 175  276.9   48.9       41.8   27.0
# 176  248.4   30.2       20.3   20.2
# 183  287.6   43.0       71.8   26.2
# 185  205.0   45.1       19.6   22.6
# 198  283.6   42.0       66.2   25.5

# %%
# Indexing rows based on multiple conditions

Ads[(Ads["TV"] > 200) & (Ads["Sales"] > 20)]
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 17   281.4   39.6       55.8   24.4
# 30   292.9   28.3       43.2   21.4
# 36   266.9   43.8        5.0   25.4
# 39   228.0   37.7       32.0   21.5
# 42   293.6   27.7        1.8   20.7
# 47   239.9   41.5       18.5   23.2
# 52   216.4   41.7       39.6   22.6
# 54   262.7   28.8       15.9   20.2
# 58   210.8   49.6       37.7   23.8
# 61   261.3   42.7       54.7   24.2
# 69   216.8   43.9       27.2   22.3
# 84   213.5   43.0       33.8   21.7
# 93   250.9   36.5       72.3   22.2
# 98   289.7   42.3       51.2   25.4
# 101  296.4   36.3      100.9   23.8
# 104  238.2   34.3        5.3   20.7
# 111  241.7   38.0       23.2   21.8
# 128  220.3   49.0        3.2   24.7
# 137  273.7   28.9       59.7   20.8
# 142  220.5   33.2       37.9   20.1
# 147  243.2   49.0       44.3   25.4
# 175  276.9   48.9       41.8   27.0
# 176  248.4   30.2       20.3   20.2
# 183  287.6   43.0       71.8   26.2
# 185  205.0   45.1       19.6   22.6
# 198  283.6   42.0       66.2   25.5

# %% [markdown]
# ## Exercise 2
#
# ในข้อต่อไปนี้ ให้นับแถวและคอลัมน์เริ่มจาก 0
# 1. แสดงค่าสูงสุดของข้อมูลที่อยู่ในแถวที่ 200-400 ของตัวแปร `total_bedrooms`
# 2. แสดง 3 คอลัมน์สุดท้ายของพื้นที่ที่มีจำนวนห้องนอน (`total_bedrooms`) มากกว่า 900 ห้อง

# %%
# WRITE YOUR CODE HERE

# %% [markdown]
# ## Plotting

# %%
housing.hist(bins=20, figsize=(15,15))
plt.show()

# %%
housing.head(3)

# %%
housing.plot.scatter(x="longitude", y="latitude");

# %%
housing.plot.scatter(x="longitude", y="latitude", alpha=0.1)

# %%
corr_matrix = housing.corr()

corr_matrix

# %% [markdown]
# ### Grouping
#
# พิจารณา Anscombe dataset ข้างล่างนี้

# %%
import seaborn as sns

df = sns.load_dataset('anscombe')

# %%
df

# %%
groups = df.groupby('dataset')

# %%
groups.get_group('I')

# %%
groups.max()

# %% [markdown]
# ## Exercise 3
#
# 1. คำนวณค่า mean, standard deviation และ correlation matrix ของแต่ละกลุ่ม
# 2. สร้าง scatter plot ของแต่ละกลุ่มด้วย `groups.plot.scatter(...)`
# 3. จาก 2 ข้อข้างบน ให้บอกว่าทำไมการคำนวณค่าสถิติต่างๆ (mean, s.d., correlation) ยังไม่เพียงพอที่จะศึกษาข้อมูลชุดหนึ่ง
